# %%
# =============================================================
# RUNTIME CONFIGURATION
#
# Loads the frozen runtime manifest from the Unity Catalog volume
# and exposes every path, endpoint and identifier as a named
# constant. Executed first via %run so all subsequent notebooks
# can reference these globals without repeating path strings.
# =============================================================

import json

RUNTIME_CONFIG_FILE = (
    "/Volumes/demodatabrciks123/"
    "creditrisk/raw_file/runtime/"
    "runtime_configuration.json"
)

with open(RUNTIME_CONFIG_FILE, "r", encoding="utf-8") as file:
    RUNTIME_CONFIG = json.load(file)

AI_SEARCH_ENDPOINT       = RUNTIME_CONFIG["ai_search_endpoint"]
AI_SEARCH_INDEX          = RUNTIME_CONFIG["ai_search_index"]
REGISTERED_MODEL_URI     = RUNTIME_CONFIG["registered_model_uri"]
DOCUMENT_FACTS_FILE      = RUNTIME_CONFIG["document_facts_file"]
DOCUMENT_MANIFEST_FILE   = RUNTIME_CONFIG["document_manifest_file"]
MODEL_CONFIGURATION_FILE = RUNTIME_CONFIG["model_configuration_file"]
POLICY_VERSION           = RUNTIME_CONFIG["policy_version"]

print("Runtime configuration loaded.")
print(f"  Model URI      : {REGISTERED_MODEL_URI}")
print(f"  AI Search index: {AI_SEARCH_INDEX}")
print(f"  Policy version : {POLICY_VERSION}")
